# %%
import cv2 as cv

# %%
img = cv.imread("/Users/sakshamchauhan/Downloads/Machine-Learning/Machine_Learning/OpenCV/Lecture-1/dog.jpg")
# USING Function
new_img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
# USING numpy
new = img[:,:,::-1]
# Gray
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
print(img.shape)
# Out:
# (980, 980, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()
plt.imshow(new_img) # Function
plt.show()
plt.imshow(new) # Numpy
plt.show()
plt.imshow(gray) # Gray
plt.show()
